# %%
import numpy as np
import pandas as pd 
import os
os.chdir("C:/Users/hp/Downloads/HeartDiseasePrediction/Heart Disease Prediction/Dataset")

# %%
df = pd.read_csv("HeartDisease.csv")

# %%
df
# Out:
#      age  gender  chest_pain  rest_bps  cholestrol  fasting_blood_sugar  \
# 0     63       1           3       145         233                    1
# 1     37       1           2       130         250                    0
# 2     41       0           1       130         204                    0
# 3     56       1           1       120         236                    0
# 4     57       0           0       120         354                    0
# ..   ...     ...         ...       ...         ...                  ...
# 298   57       0           0       140         241                    0
# 299   45       1           3       110         264                    0
# 300   68       1           0       144         193                    1
# 301   57       1           0       130         131                    0
# 302   57       0           1       130         236                    0
#
#      rest_ecg  thalach  exer_angina  old_peak  slope  ca  thalassemia  target
# ...

# %%
df.head()
# Out:
#    age  gender  chest_pain  rest_bps  cholestrol  fasting_blood_sugar  \
# 0   63       1           3       145         233                    1
# 1   37       1           2       130         250                    0
# 2   41       0           1       130         204                    0
# 3   56       1           1       120         236                    0
# 4   57       0           0       120         354                    0
#
#    rest_ecg  thalach  exer_angina  old_peak  slope  ca  thalassemia  target
# 0         0      150            0       2.3      0   0            1       1
# 1         1      187            0       3.5      0   0            2       1
# 2         0      172            0       1.4      2   0            2       1
# 3         1      178            0       0.8      2   0            2       1
# 4         1      163            1       0.6      2   0            2       1

# %%
df.tail()
# Out:
#      age  gender  chest_pain  rest_bps  cholestrol  fasting_blood_sugar  \
# 298   57       0           0       140         241                    0
# 299   45       1           3       110         264                    0
# 300   68       1           0       144         193                    1
# 301   57       1           0       130         131                    0
# 302   57       0           1       130         236                    0
#
#      rest_ecg  thalach  exer_angina  old_peak  slope  ca  thalassemia  target
# 298         1      123            1       0.2      1   0            3       0
# 299         1      132            0       1.2      1   0            3       0
# 300         1      141            0       3.4      1   2            3       0
# 301         1      115            1       1.2      1   1            3       0
# 302         0      174            0       0.0      1   1            2       0

# %%
df.shape
# Out:
# (303, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  303 non-null    int64
#  1   gender               303 non-null    int64
#  2   chest_pain           303 non-null    int64
#  3   rest_bps             303 non-null    int64
#  4   cholestrol           303 non-null    int64
#  5   fasting_blood_sugar  303 non-null    int64
#  6   rest_ecg             303 non-null    int64
#  7   thalach              303 non-null    int64
#  8   exer_angina          303 non-null    int64
#  9   old_peak             303 non-null    float64
#  10  slope                303 non-null    int64
#  11  ca                   303 non-null    int64
#  12  thalassemia          303 non-null    int64
#  13  target               303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.isna().sum()
# Out:
# age                    0
# gender                 0
# chest_pain             0
# rest_bps               0
# cholestrol             0
# fasting_blood_sugar    0
# rest_ecg               0
# thalach                0
# exer_angina            0
# old_peak               0
# slope                  0
# ca                     0
# thalassemia            0
# target                 0
# dtype: int64

# %% [markdown]
# ## exploratory data analysis

# %%
pd.crosstab(df.age,df.target).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='age'>

# %%
pd.crosstab(df.rest_ecg,df.target).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='rest_ecg'>

# %%
import seaborn as sns
sns.countplot(df['rest_ecg'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='rest_ecg', ylabel='count'>

# %%
sns.countplot(x = "rest_ecg", hue = "target", data = df)
# Out:
# <AxesSubplot:xlabel='rest_ecg', ylabel='count'>

# %% [markdown]
# ##### 1.When Potassium level 1 patient has heart disease rate is high and when potasssium level is 0 patient has not heart disease rate iss  high.
# #####  2.When potassium level 11 patient has not heart disease count is low as  comapre to potasium level at 0.
# #####  3. aas comapre to potaassium  level 0 and 1 potassium level 2 heart diesaase rate and not heart dieases both low.

# %%
import matplotlib.pyplot as plt
#Correlation plot
corr=df.corr()
plt.subplots(figsize=(10,6))
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
#target is highly correlation with saleprice has a correlation coeff of  0.82
#unique values of targget
df.target.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
sns.barplot(df.target, df.age)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='target', ylabel='age'>

# %%
sns.set(style='ticks')
sns.pairplot(df, size=3, kind='reg')
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\axisgrid.py:1912: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
numeric=df.select_dtypes(exclude=['object'])

# %%
numeric

# %%
categorical=df.select_dtypes(include='object')

# %%
categorical

# %%
numeric.columns

# %%
numeric.isna().sum()

# %%
y=numeric['target']

# %%
y.head()

# %%
x = numeric.drop(['target'], axis=1, inplace=True)

# %%
numeric.columns

# %%
x=numeric

# %%
x.columns

# %% [markdown]
# ## Split Data into train and test

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,random_state=100)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr2=LogisticRegression(max_iter=1000)

# %%
#fit the model
lr.fit(x_train,y_train)

# %%
lr2.fit(x_train,y_train)

# %%
#making predictions using data
y_pred=lr.predict(x_test)

# %%
y_pred

# %%
#making predictions using data
y_pred2=lr2.predict(x_test)

# %%
y_pred2

# %%
#getting model performance metrics
from sklearn.metrics import accuracy_score,precision_score,recall_score,confusion_matrix,roc_auc_score

# %%
confusion_matrix(y_test,y_pred)

# %%
confusion_matrix(y_test,y_pred2)

# %%
from sklearn.metrics import f1_score

# %%
accuracy = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

# %%
print("Accuracy is:",accuracy)
print("F1 score is:",f1)
print("Precision score is:",precision)
print("Recall score is:",recall)

# %%
accuracy = accuracy_score(y_test, y_pred2)
f1 = f1_score(y_test, y_pred2)
precision = precision_score(y_test, y_pred2)
recall = recall_score(y_test, y_pred2)

# %%
print("Accuracy is:",accuracy)
print("F1 score is:",f1)
print("Precision score is:",precision)
print("Recall score is:",recall)

# %% [markdown]
# ## Performing Logit Model

# %%
import statsmodels.api as sm

# %%
logit_model = sm.Logit(list(y_train),x_train)

# %%
result = logit_model.fit()

# %%
result.summary2()

# %% [markdown]
# ## Standard scaling

# %%
numeric.head(5)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scale=StandardScaler()

# %%
x_sc=scale.fit_transform(numeric)

# %%
y_arr=np.asarray(y_train)

# %%
x_arr=np.asarray(x_train)

# %%
logit_mod2=sm.Logit(y_arr,x_arr)

# %%
result2=logit_mod2.fit()

# %%
result2.summary2()

# %%
logit_mod3=sm.Logit(y_train.values.tolist(),x_train.values.tolist())

# %%
result3=logit_mod3.fit()

# %%
result3.summary2()

# %% [markdown]
# ## Performing SGD

# %%
# Importing Required Liabraries
from sklearn.linear_model import SGDRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import SGDClassifier

# %%
X = x_train

# %%
Y = y_train

# %%
clf = make_pipeline(StandardScaler(), SGDClassifier(tol=1e-3))

# %%
clf.fit(X,Y)

# %%
y_pred =clf.predict(x_test)

# %%
y_pred[0:5]

# %%
y_test[0:5]

# %%
clf.score(x_test,y_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

# %%
print("Accuracy is:",accuracy)
print("F1 score is:",f1)
print("Precision score is:",precision)
print("Recall score is:",recall)
